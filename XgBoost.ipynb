# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
hit = pd.read_csv("Hitters.csv")
df = hit.copy()
df = df.dropna()
dms = pd.get_dummies(df[["League", "Division", "NewLeague"]])

y = df["Salary"]
X_ = df.drop(["Salary", "League", "Division", "NewLeague"], axis=1).astype("float64")
X = pd.concat([X_, dms[["League_N", "Division_W", "NewLeague_N"]]], axis = 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 25, random_state = 42)

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.7.5-py3-none-macosx_12_0_arm64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 2.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy in /Users/batuhanbilgili/opt/anaconda3/lib/python3.9/site-packages (from xgboost) (1.21.5)
# Requirement already satisfied: scipy in /Users/batuhanbilgili/opt/anaconda3/lib/python3.9/site-packages (from xgboost) (1.9.1)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.7.5

# %%
import xgboost as xgb

# %%
# xgboost'u performanslı kullanmak için kendi değişkenleri üzerinden kullanmak gerekiyor
DM_train = xgb.DMatrix(data = X_train, label = y_train)
DM_test = xgb.DMatrix(data = X_test, label = y_test)

# %%
from xgboost import XGBRegressor

# %%
xgb = XGBRegressor().fit(X_train, y_train)

# %% [markdown]
# ## Tahmin

# %%
y_pred = xgb.predict(X_test)

print("Tahmin hatası: ",np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Tahmin hatası:  329.43195380236057

# %% [markdown]
# ## Model Tuning

# %%
xgb_grid = {
    "colsample_bytree": [0.4, 0.5, 0.6, 0.9, 1],
    "n_estimators": [100, 200, 500, 1000],
    "max_depth": [2,3,4,5,6],
    "learning_rate": [0.1, 0.01, 0.5]
}

# %%
xgb = XGBRegressor()

xgb_cv = GridSearchCV(xgb, 
                      param_grid = xgb_grid, 
                      cv = 10, 
                      n_jobs = -1, 
                      verbose = 2)

xgb_cv.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 300 candidates, totalling 3000 fits
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=3, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=3, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=3, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=3, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.5, max_depth=4, n_estimators=200; total time=   0.1s
# ...
# [CV] END colsample_bytree=0.6, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.6, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.6, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.6, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.6, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=2, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=2, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=3, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=3, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=4, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=4, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=5, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=5, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=5, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.6, learning_rate=0.5, max_depth=5, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=3, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=3, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=4, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=4, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=5, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=5, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=5, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=5, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.2s
# GridSearchCV(cv=10,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None, gpu_id=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None,...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None, n_estimators=100,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     predictor=None, random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.4, 0.5, 0.6, 0.9, 1],
#                          'learning_rate': [0.1, 0.01, 0.5],
#                          'max_depth': [2, 3, 4, 5, 6],
#                          'n_estimators': [100, 200, 500, 1000]},
#              verbose=2)

# %%
xgb_cv.best_params_
# Out:
# {'colsample_bytree': 0.5,
#  'learning_rate': 0.1,
#  'max_depth': 2,
#  'n_estimators': 500}

# %%
# En iyi değerler ile model oluşturma
xgb_tuned = XGBRegressor(learning_rate = 0.1, 
                         max_depth = 2,
                         n_estimators = 500,
                         colsample_bytree = 0.5)

xgb_tuned = xgb_tuned.fit(X_train, y_train)

# %%
y_pred = xgb_tuned.predict(X_test)

print("Tahmin hatası: ",np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Tahmin hatası:  304.3503871237262
